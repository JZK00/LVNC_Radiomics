# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('./combine-1228.csv',encoding='gbk')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   End                               96 non-null     int64
#  1   Shape Flatness                    96 non-null     float64
#  2   Shape Elongation                  96 non-null     float64
#  3   GLCM ClusterShade                 96 non-null     float64
#  4   Firstorder 10Percentile           96 non-null     float64
#  5   Firstorder Minimum                96 non-null     float64
#  6   Shape Maximum 2D Diameter Column  96 non-null     float64
#  7   GLSZM Small Area Emphasis         96 non-null     float64
#  8   Shape Maximum 2D Diameter Row     96 non-null     float64
#  9   Firstorder Mean                   96 non-null     float64
#  10  Shape Surface Volume Ratio        96 non-null     float64
# ...

# %%
df.head()
# Out:
#    End  Shape Flatness  Shape Elongation  GLCM ClusterShade  \
# 0    0        0.089947          0.956562        1523.214082
# 1    0        0.092819          0.963362       28835.622890
# 2    0        0.078033          0.951846        2792.368275
# 3    1        0.088140          0.913976        6464.951013
# 4    0        0.076208          0.980006       20815.069160
#
#    Firstorder 10Percentile  Firstorder Minimum  \
# 0                -8.521614          -82.271643
# 1               -14.571660          -87.111764
# 2                -4.293009          -73.745260
# 3                 5.594602          -55.817565
# 4                40.708389          -77.359506
#
#    Shape Maximum 2D Diameter Column  GLSZM Small Area Emphasis  \
# 0                         77.447115                   0.736896
# 1                         93.867462                   0.830169
# 2                         90.005555                   0.800328
# ...

# %%
plt.figure(figsize=(20,20)) 
sns.heatmap(df.drop("End", axis=1).corr(),annot=True,cmap='Blues')
#plt.savefig("sns.jpg",bbox_inches = 'tight',dpi=1200) # save
plt.show()

# %%
plt.figure(figsize=(20,20)) 
ax = sns.heatmap(df.drop("End", axis=1).corr(),annot=True,cmap='Blues',cbar=False)

label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=0, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=45, horizontalalignment='right')

#plt.savefig("sns1.jpg",bbox_inches = 'tight',dpi=1200)
plt.show()
